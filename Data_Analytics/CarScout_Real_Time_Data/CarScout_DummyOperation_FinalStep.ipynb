# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import re
import seaborn as sns
# Out:
# C:\Users\iayav\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
df = pd.read_csv('Capstone_project_step3_Ahmet')
df.T
# Out:
#                              0                 1               2      \
# make_model                 Audi A1           Audi A1         Audi A1
# body_type                   Sedans            Sedans          Sedans
# price                        15770             14500           14640
# vat                 VAT deductible  Price negotiable  VAT deductible
# km                         56013.0           80000.0         83450.0
# prev_owner                     2.0               1.0             1.0
# hp                            66.0             141.0            85.0
# type                          Used              Used            Used
# first_registration          2016.0            2017.0          2016.0
# body_color                   Black               Red           Black
# nr_of_doors                    5.0               3.0             4.0
# nr_of_seats                    5.0               4.0             4.0
# gearing_type             Automatic         Automatic       Automatic
# ...

# %% [markdown]
# Let's obtain the dummies.

# %% [markdown]
# ### Make & Model

# %%
one_hot = pd.get_dummies(df, columns = ['make_model'])
df = one_hot
df
# Out:
#       body_type  price               vat            km  prev_owner     hp  \
# 0        Sedans  15770    VAT deductible  56013.000000         2.0   66.0
# 1        Sedans  14500  Price negotiable  80000.000000         1.0  141.0
# 2        Sedans  14640    VAT deductible  83450.000000         1.0   85.0
# 3        Sedans  14500    VAT deductible  73000.000000         1.0   66.0
# 4        Sedans  16790    VAT deductible  16200.000000         1.0   66.0
# ...         ...    ...               ...           ...         ...    ...
# 14360       Van  39980    VAT deductible    100.000000         1.0  118.0
# 14361       Van  39950    VAT deductible  34130.127828         1.0  147.0
# 14362       Van  39950    VAT deductible  34130.127828         1.0  147.0
# 14363       Van  39875    VAT deductible     15.000000         1.0  146.0
# 14364       Van  39700    VAT deductible     10.000000         1.0  147.0
#
#                  type  first_registration body_color  nr_of_doors  ...  \
# ...

# %% [markdown]
# ### Body Type

# %%
one_hot = pd.get_dummies(df, columns = ['body_type'])
df = one_hot
df
# Out:
#        price               vat            km  prev_owner     hp  \
# 0      15770    VAT deductible  56013.000000         2.0   66.0
# 1      14500  Price negotiable  80000.000000         1.0  141.0
# 2      14640    VAT deductible  83450.000000         1.0   85.0
# 3      14500    VAT deductible  73000.000000         1.0   66.0
# 4      16790    VAT deductible  16200.000000         1.0   66.0
# ...      ...               ...           ...         ...    ...
# 14360  39980    VAT deductible    100.000000         1.0  118.0
# 14361  39950    VAT deductible  34130.127828         1.0  147.0
# 14362  39950    VAT deductible  34130.127828         1.0  147.0
# 14363  39875    VAT deductible     15.000000         1.0  146.0
# 14364  39700    VAT deductible     10.000000         1.0  147.0
#
#                  type  first_registration body_color  nr_of_doors  \
# 0                Used              2016.0      Black          5.0
# ...

# %% [markdown]
# ### VAT

# %%
one_hot = pd.get_dummies(df, columns = ['vat'])
df = one_hot
df
# Out:
#        price            km  prev_owner     hp            type  \
# 0      15770  56013.000000         2.0   66.0            Used
# 1      14500  80000.000000         1.0  141.0            Used
# 2      14640  83450.000000         1.0   85.0            Used
# 3      14500  73000.000000         1.0   66.0            Used
# 4      16790  16200.000000         1.0   66.0            Used
# ...      ...           ...         ...    ...             ...
# 14360  39980    100.000000         1.0  118.0  Pre-registered
# 14361  39950  34130.127828         1.0  147.0             New
# 14362  39950  34130.127828         1.0  147.0             New
# 14363  39875     15.000000         1.0  146.0  Pre-registered
# 14364  39700     10.000000         1.0  147.0  Pre-registered
#
#        first_registration body_color  nr_of_doors  nr_of_seats gearing_type  \
# 0                  2016.0      Black          5.0          5.0    Automatic
# ...

# %% [markdown]
# ### Type

# %%
one_hot = pd.get_dummies(df, columns = ['type'])
df = one_hot
df
# Out:
#        price            km  prev_owner     hp  first_registration body_color  \
# 0      15770  56013.000000         2.0   66.0              2016.0      Black
# 1      14500  80000.000000         1.0  141.0              2017.0        Red
# 2      14640  83450.000000         1.0   85.0              2016.0      Black
# 3      14500  73000.000000         1.0   66.0              2016.0      Brown
# 4      16790  16200.000000         1.0   66.0              2016.0      Black
# ...      ...           ...         ...    ...                 ...        ...
# 14360  39980    100.000000         1.0  118.0              2019.0      White
# 14361  39950  34130.127828         1.0  147.0              2019.0      Black
# 14362  39950  34130.127828         1.0  147.0              2019.0       Grey
# 14363  39875     15.000000         1.0  146.0              2019.0      White
# 14364  39700     10.000000         1.0  147.0              2019.0       Grey
#
# ...

# %% [markdown]
# ### Body_Color

# %%
one_hot = pd.get_dummies(df, columns = ['body_color'])
df = one_hot
df
# Out:
#        price            km  prev_owner     hp  first_registration  \
# 0      15770  56013.000000         2.0   66.0              2016.0
# 1      14500  80000.000000         1.0  141.0              2017.0
# 2      14640  83450.000000         1.0   85.0              2016.0
# 3      14500  73000.000000         1.0   66.0              2016.0
# 4      16790  16200.000000         1.0   66.0              2016.0
# ...      ...           ...         ...    ...                 ...
# 14360  39980    100.000000         1.0  118.0              2019.0
# 14361  39950  34130.127828         1.0  147.0              2019.0
# 14362  39950  34130.127828         1.0  147.0              2019.0
# 14363  39875     15.000000         1.0  146.0              2019.0
# 14364  39700     10.000000         1.0  147.0              2019.0
#
#        nr_of_doors  nr_of_seats gearing_type  displacement  cylinders  ...  \
# 0              5.0          5.0    Automatic        1422.0        3.0  ...
# ...

# %% [markdown]
# ### Gearing Type

# %%
one_hot = pd.get_dummies(df, columns = ['gearing_type'])
df = one_hot
df
# Out:
#        price            km  prev_owner     hp  first_registration  \
# 0      15770  56013.000000         2.0   66.0              2016.0
# 1      14500  80000.000000         1.0  141.0              2017.0
# 2      14640  83450.000000         1.0   85.0              2016.0
# 3      14500  73000.000000         1.0   66.0              2016.0
# 4      16790  16200.000000         1.0   66.0              2016.0
# ...      ...           ...         ...    ...                 ...
# 14360  39980    100.000000         1.0  118.0              2019.0
# 14361  39950  34130.127828         1.0  147.0              2019.0
# 14362  39950  34130.127828         1.0  147.0              2019.0
# 14363  39875     15.000000         1.0  146.0              2019.0
# 14364  39700     10.000000         1.0  147.0              2019.0
#
#        nr_of_doors  nr_of_seats  displacement  cylinders     fuel  ...  \
# 0              5.0          5.0        1422.0        3.0   Diesel  ...
# ...

# %% [markdown]
# ### Fuel

# %%
one_hot = pd.get_dummies(df, columns = ['fuel'])
df = one_hot
df
# Out:
#        price            km  prev_owner     hp  first_registration  \
# 0      15770  56013.000000         2.0   66.0              2016.0
# 1      14500  80000.000000         1.0  141.0              2017.0
# 2      14640  83450.000000         1.0   85.0              2016.0
# 3      14500  73000.000000         1.0   66.0              2016.0
# 4      16790  16200.000000         1.0   66.0              2016.0
# ...      ...           ...         ...    ...                 ...
# 14360  39980    100.000000         1.0  118.0              2019.0
# 14361  39950  34130.127828         1.0  147.0              2019.0
# 14362  39950  34130.127828         1.0  147.0              2019.0
# 14363  39875     15.000000         1.0  146.0              2019.0
# 14364  39700     10.000000         1.0  147.0              2019.0
#
#        nr_of_doors  nr_of_seats  displacement  cylinders  co_2_emission  ...  \
# 0              5.0          5.0        1422.0        3.0          992.0  ...
# ...

# %% [markdown]
# ### Extras

# %%
one_hot = pd.get_dummies(df, columns = ['extras'])
df = one_hot
df
# Out:
#        price            km  prev_owner     hp  first_registration  \
# 0      15770  56013.000000         2.0   66.0              2016.0
# 1      14500  80000.000000         1.0  141.0              2017.0
# 2      14640  83450.000000         1.0   85.0              2016.0
# 3      14500  73000.000000         1.0   66.0              2016.0
# 4      16790  16200.000000         1.0   66.0              2016.0
# ...      ...           ...         ...    ...                 ...
# 14360  39980    100.000000         1.0  118.0              2019.0
# 14361  39950  34130.127828         1.0  147.0              2019.0
# 14362  39950  34130.127828         1.0  147.0              2019.0
# 14363  39875     15.000000         1.0  146.0              2019.0
# 14364  39700     10.000000         1.0  147.0              2019.0
#
#        nr_of_doors  nr_of_seats  displacement  cylinders  co_2_emission  ...  \
# 0              5.0          5.0        1422.0        3.0          992.0  ...
# ...

# %%
df = pd.get_dummies(df)
df.sample(50)

# %%
df.to_csv("Capstone_project_finalstep_Ahmet", encoding='utf-8', index=False)

# %%
filter()
